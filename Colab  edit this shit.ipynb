# %% [markdown]
# # This will download files (most likely music) from my mega import folder to mega folder in /content/, extract zip,rar,7z files, delete the archive files, convert png to jpg, convert all flac,aiff,wav files to opus, delete png,flac,aiff,wav files, archive them with each single archive being 300mb in the rar folder of /My Drive/
#
# Don't forget to change name of the archive.
#
# Don't forget to change directory to /content/mega/ before downloading files form mega.
#
# Use "-p'your_password'" in 7z command if file is password protected.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd "/content/"

# !curl https://rclone.org/install.sh | sudo bash -s beta
# !apt install opus-tools
# !apt install imagemagick
# !wget https://www.dropbox.com/s/4wwqn90n7z2mxrf/rclone.conf
# !wget https://www.dropbox.com/s/evpwifhq4eb1mm2/exclude.txt

# !mkdir "/root/.config/rclone/"
# !mv "/content/rclone.conf" "/root/.config/rclone/"

# %%
# %cd "/content/"
# !rclone move --checkers=10 --multi-thread-cutoff=10M --multi-thread-streams=10 --retries=10 --use-mmap --buffer-size=2000M --exclude-from=/content/exclude.txt --mega-hard-delete --transfers=10 "mega:a" "/content/mega/"

# %%
# %cd /content/mega/
# !du -h

# %%
# %cd "/content/mega/"

# !find . -name "*.*" -type 'f' -size -1k -delete

# !find -name "*.zip" -exec bash -c '7z -o"${0/.zip}" x "{}"' {} \;
# !find -name "*.rar" -exec bash -c '7z -o"${0/.rar}" x "{}"' {} \;
# !find -name "*.7z" -exec bash -c '7z -o"${0/.7z}" x "{}"' {} \;


# !find . -type f -iname \*.7z -delete
# !find . -type f -iname \*.zip -delete
# !find . -type f -iname \*.rar -delete

# !find -name "*.png" -exec bash -c 'convert "{}" -quality 90 "${0/.png}.jpg"' {} \;
# !find -name "*.flac" -exec bash -c 'opusenc --quiet --discard-pictures --bitrate 192 "{}" "${0/.flac}.opus"' {} \;
# !find -name "*.flac" -exec bash -c 'ffmpeg -loglevel quiet -n -i "{}" -c:a libopus -b:a 192k "${0/.flac}.opus"' {} \;
# !find -name "*.aiff" -exec bash -c 'opusenc --quiet --discard-pictures --bitrate 192 "{}" "${0/.aiff}.opus"' {} \;
# !find -name "*.aiff" -exec bash -c 'ffmpeg -loglevel quiet -n -i "{}" -c:a libopus -b:a 192k "${0/.aiff}.opus"' {} \;
# !find -name "*.wav" -exec bash -c 'opusenc --quiet --discard-pictures --bitrate 192 "{}" "${0/.wav}.opus"' {} \;
# !find -name "*.wav" -exec bash -c 'ffmpeg -loglevel quiet -n -i "{}" -c:a libopus -b:a 192k "${0/.wav}.opus"' {} \;

# !find . -type f -iname \*.png -delete
# !find . -type f -iname \*.flac -delete
# !find . -type f -iname \*.aiff -delete
# !find . -type f -iname \*.wav -delete

# %%
# !mkdir "/content/drive/My Drive/rar/"
# %cd "/content/drive/My Drive/rar/"
!7z -v300m -mx1 -mmt4 a "some_shitz 2" "/content/mega/"
# %cd "/content/"

# %%
# !rm -rf "/content/mega/"

# %% [markdown]
# # This download manga to "/content", then archive them into group of 300MB each file (directly saving them into /My Drive/).
#
# Don't forget to change the archive name.
#
# If downloading from mangadex, always use
#
#     --chapter-filter "lang == 'en'"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install gallery-dl

# %%
# !gallery-dl -g https://mangadex.org/title/23569/gokushufudou-the-way-of-the-house-husband

# %%
# %cd "/content/"

# !gallery-dl -u emfyr -p YESw3eY3AcxtuhyCXXW4Fm --ugoira-conv "https://www.pixiv.net/en/users/648285"

# !mkdir "/content/drive/My Drive/Manga/"
# %cd "/content/gallery-dl/"
# !find . -maxdepth 2 -mindepth 2 -type d -exec bash -c '7z -v300m -mx1 -mmt4 a "{}" "{}"' {} \;
# !find -name "*.7z.*" -exec bash -c 'mv "{}" "/content/drive/My Drive/Manga/"' {} \;

# %%
# %cd "/content/"
# !rm -rf "/content/gallery-dl/"

# %%
                                                   OR

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install manga-py

# %%
# %cd "/content/"

# !manga-py -t 30 -f --no-progress "Link"

# !mkdir "/content/drive/My Drive/Manga/"
# %cd "/content/Manga/"
# !find . -mindepth 1 -maxdepth 1 -type d -exec bash -c '7z -v300m -mx1 -mmt4 a "{}" "{}"' {} \;
# !find -name "*.7z.*" -exec bash -c 'mv "{}" "/content/drive/My Drive/Manga/"' {} \;

# %%
# %cd "/content/"
# !rm -rf "/content/Manga/"

# %% [markdown]
# # Download torrent to wherever you want (-d)
#
#
# -This is important. If link is a magnet link, use      -d "output directory"
#
# -Use for torrent file    -T file.torrent
#
# -Following only work if file is torrent (To show files)   -S
#
#
# -This would well slect files to download
#
#     --select-file=x-y,z,a-b

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt install aria2

# %%
# !aria2c --bt-metadata-only=true --bt-save-metadata=true -q "magnet:?xt=urn:btih:403f15f971a36850bf8b9aabbb0df07779161bd4&dn=Band+Of+Brothers+HBO+Mini-Series+1080p+5.1Ch+BluRay+ReEnc-DeeJay&tr=udp%3A%2F%2Ftracker.leechers-paradise.org%3A6969&tr=udp%3A%2F%2Ftracker.openbittorrent.com%3A80&tr=udp%3A%2F%2Fopen.demonii.com%3A1337&tr=udp%3A%2F%2Ftracker.coppersurfer.tk%3A6969&tr=udp%3A%2F%2Fexodus.desync.com%3A6969"

# %%
# !rm -rf "/content/drive/My Drive/Series/HoC"

# %%
# !aria2c --max-connection-per-server=16 --split=16 --seed-time=0 --download-result=full --auto-save-interval=20 --bt-max-open-files=10000 --bt-max-peers=0 --save-session-interval=20 --summary-interval=10 -d "/content/drive/My Drive/Series/PB"

# %%
# %cd /content/
# !wget https://github.com/d-fi/releases/releases/download/1.2.1/d-fi-linux-x64.zip

# %%
!7z -o* x /content/d-fi-linux-x64.zip

# %%
# %cd d-fi-linux-x64

# %%
# %cd "/content/d-fi-linux-x64"
# !chmod +x ./d-fi
# !mkdir "/content/drive/My Drive/Music"

# %%
# !/content/d-fi-linux-x64/d-fi -c 99 https://open.spotify.com/album/1n8ESe5nt7EeuZedZUI3yu
# Out:
# ╔══════════════════════════════════════════════════════════╗
# ║                    d-fi (1.2.1)                          ║
# ╠══════════════════════════════════════════════════════════╣
#  ♥  REPO   ║ https://notabug.org/sayem314/d-fi             ║
# ╠══════════════════════════════════════════════════════════╣
#  ♥  DONATE ║ https://sayem.eu.org/donate                   ║
# ╚══════════════════════════════════════════════════════════╝
#
#   [==--------------------------------------] | 4% | Shelter  [===-------------------------------------] | 7% | Shelter  [=====-----------------------------------] | 13% | Shelter  [======----------------------------------] | 16% | Shelter  [========--------------------------------] | 19% | Shelter  [=========-------------------------------] | 22% | Shelter  [==========------------------------------] | 25% | Shelter  [============----------------------------] | 31% | Shelter  [==============--------------------------] | 34% | Shelter  [===============-------------------------] | 37% | Shelter  [================------------------------] | 40% | Shelter  [=================-----------------------] | 43% | Shelter  [==================----------------------] | 46% | Shelter  [=====================-------------------] | 52% | Shelter  [======================------------------] | 55% | Shelter  [=======================-----------------] | 58% | Shelter  [========================----------------] | 61% | Shelter  [==========================--------------] | 64% | Shelter  [===========================-------------] | 67% | Shelter  [=============================-----------] | 73% | Shelter  [==============================----------] | 76% | Shelter  [================================--------] | 79% | Shelter  [=================================-------] | 82% | Shelter  [==================================------] | 85% | Shelter  [===================================-----] | 88% | Shelter  [=====================================---] | 94% | Shelter  [=======================================-] | 97% | Shelter  [========================================] | 100% | Shelter
# ✔  success   Porter Robinson & Madeon - Shelter
#   › /content/d-fi-linux-x64/Music/Porter Robinson & Madeon - Shelter/01 - Shelter.mp3
# ☒  complete  Finished downloading album "Shelter"

# %%
# !man parallel

# %%
# !sed -i -e 's/\r$//' /content/d-fi-linux-x64/para.sh

# %%
# !/content/d-fi-linux-x64/para.sh "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/7716990" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/10534682" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/10534914" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/10534924" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/10534980" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/10535076" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/10535438" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/11253764" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/11849020" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/12922222" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/13891480" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/15386683" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/41221251" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/44993941" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/51760862" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/54060462" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/61302922" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/61325782" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/63630332" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/79211732" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/79211752" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/79211772" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/79211852" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/79212422" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/80207982" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/96522082" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/100525832" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/113947752" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/123308582" "/content/d-fi-linux-x64/d-fi -c 99 https://www.deezer.com/en/album/123817962"
# Out:
#   [===================================-----] | 88% | Only Not Equal Lonely
#
#   [======================================--] | 94% | Ashiato Compass
#   [========================================] | 100% | Rising Hope
#   [========================================] | 100% | Tsuyogari Fanfare
#
#
#
# ✔  success   LiSA - HANDS and SMiLE
#   › /content/d-fi-linux-x64/Music/LiSA - Oath Sign/03 - HANDS and SMiLE.mp3
# ✔  success   LiSA - Confidence Driver
#   › /content/d-fi-linux-x64/Music/LiSA - Oath Sign/02 - Confidence Driver.mp3
# ✔  success   LiSA - Oath Sign (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Oath Sign/04 - Oath Sign (Instrumental).mp3
# ✔  success   LiSA - Oath Sign
#   › /content/d-fi-linux-x64/Music/LiSA - Oath Sign/01 - Oath Sign.mp3
# ☒  complete  Finished downloading album "Oath Sign"
#
#
#
#   [=================================-------] | 84% | Mushokutoumei
#
#   [========================================] | 100% | Escape Game
#   [========================================] | 100% | Believe in Myself
#   [========================================] | 100% | Miraikaze
#   [========================================] | 100% | Eien
#   [========================================] | 100% | Mousou Controller
#
#
#
#   [========================================] | 100% | L.Miranic  [========================================] | 100% | Orange Cider
#
#
#   [======================================--] | 96% | Rally Go Round  [====================================----] | 90% | Bright Flight
#   [====================================----] | 89% | Tokyo Love Song
#
#
#   [====================================----] | 89% | Only Not Equal Lonely
#
#
#
#
#
#   [======================================--] | 94% | Ring a Bell
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Risky
#
#
#
#   [========================================] | 100% | ID  [========================================] | 100% | Gurenge
#
#   [======================================--] | 94% | Yakusokuno Uta
#
#   [========================================] | 100% | Shiroitoiki
#
#
#
#
#
#
#
#   [========================================] | 99% | Rally Go Round
#
#
#   [=====================================---] | 93% | Only Not Equal Lonely  [========================================] | 100% | Thrill, Risk, Heartless
# ✔  success   LiSA - Akai Wana (Who Loves It?)
#   › /content/d-fi-linux-x64/Music/LiSA - Akai Wana (Who Loves It) - ADAMAS/01 - Akai Wana (Who Loves It).mp3
# ✔  success   LiSA - Spicy World
#   › /content/d-fi-linux-x64/Music/LiSA - Akai Wana (Who Loves It) - ADAMAS/03 - Spicy World.mp3
# ✔  success   LiSA - ADAMAS
#   › /content/d-fi-linux-x64/Music/LiSA - Akai Wana (Who Loves It) - ADAMAS/02 - ADAMAS.mp3
# ✔  success   LiSA - Akai Wana (Who Loves It?)
#   › /content/d-fi-linux-x64/Music/LiSA - Akai Wana (Who Loves It) - ADAMAS/04 - Akai Wana (Who Loves It).mp3
# ☒  complete  Finished downloading album "Akai Wana (Who Loves It?) / ADAMAS"
#
#
#
#
#   [========================================] | 99% | Ring a Bell
#   [========================================] | 100% | Unlasting
# ✔  success   LiSA - Crossing Field (-English ver.-)
#   › /content/d-fi-linux-x64/Music/LiSA - Shirushi/03 - Crossing Field (-English ver.-).mp3
# ✔  success   LiSA - Shirushi
#   › /content/d-fi-linux-x64/Music/LiSA - Shirushi/01 - Shirushi.mp3
# ✔  success   LiSA - No More Time Machine
#   › /content/d-fi-linux-x64/Music/LiSA - Shirushi/02 - No More Time Machine.mp3
# ☒  complete  Finished downloading album "Shirushi"
#
#
#
#
#
#   [========================================] | 100% | Rock Mode'18
#
#   [========================================] | 100% | Hello Good Day
#
#   [========================================] | 100% | Hi Five!
#   [========================================] | 100% | No More Time Machine
#
#
#   [========================================] | 100% | Believe in Ourselves
#   [========================================] | 100% | Best Day, Best Way
#
#   [=================================-------] | 83% | Catch the Moment
# ✔  success   LiSA - Crossing Field
#   › /content/d-fi-linux-x64/Music/LiSA - Crossing Field/01 - Crossing Field.mp3
# ✔  success   LiSA - Crossing Field (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Crossing Field/04 - Crossing Field (Instrumental).mp3
# ✔  success   LiSA - Kiss Me Paradox
#   › /content/d-fi-linux-x64/Music/LiSA - Crossing Field/03 - Kiss Me Paradox.mp3
# ✔  success   LiSA - Itsukanotegami
#   › /content/d-fi-linux-x64/Music/LiSA - Crossing Field/02 - Itsukanotegami.mp3
# ☒  complete  Finished downloading album "Crossing Field"
#
#
#
#
#
#   [======================================--] | 95% | Only Not Equal Lonely
#
#
#
#
#
#   [=======================================-] | 97% | Ashiato Compass
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Rapid Life Syndrome
#
#
#   [========================================] | 100% | Mr.Launcher
#   [========================================] | 100% | L.Miranic
#   [========================================] | 100% | No More Time Machine
#
#   [========================================] | 100% | Akogare Bouenkyou
#   [========================================] | 100% | Rising Hope
#   [========================================] | 100% | Bad Sweet Trap
#
#   [========================================] | 100% | Mitsu
# ✔  success   LiSA - Unlasting
#   › /content/d-fi-linux-x64/Music/LiSA - Unlasting/01 - Unlasting.mp3
# ☒  complete  Finished downloading album "Unlasting"
#
#
#
#
#   [========================================] | 100% | KALEIDO
#
#
#
#   [=======================================-] | 97% | Only Not Equal Lonely
#   [========================================] | 100% | Bright Flight
#   [========================================] | 99% | Tokyo Love Song
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Yakusokuno Uta
#
#
#
#   [========================================] | 100% | Rally Go Round
#   [====================================----] | 89% | Blue Moon
#   [========================================] | 100% | Rally Go Round
#   [==================================------] | 86% | Catch the Moment
#   [========================================] | 100% | Empty Mermaid
#   [======================================--] | 96% | Brave Freak Out
#   [===============================---------] | 77% | Today
#   [====================================----] | 90% | Ookamito Misanga
#   [===============================---------] | 78% | Soshite Paradeha Tsuzuku
#   [====================================----] | 90% | Jump!!
#   [========================================] | 100% | The End of My World
#   [==================================------] | 84% | Little Devil Parade
#   [========================================] | 100% | Loser: Kiboutomirainimuenn
#
#
#   [========================================] | 99% | Only Not Equal Lonely
#
#
#
#   [========================================] | 100% | Ring a Bell
#
#
#
#
#   [======================================--] | 95% | Mushokutoumei
#
#
#
#
#
#
#
#
#
#
#
#
#   [======================================--] | 95% | Kimini Piero
#
#
#   [====================================----] | 91% | Orange Cider (Live at Toyos
#   [=====================================---] | 93% | Rapid Life Syndrome (Live a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Catch the Moment
#   [========================================] | 100% | Rally Go Round (Live at To
#
#
#
#
#
#   [=====================================---] | 93% | Elect Lyrical (Live at Toyo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Ashiato Compass
#
#
#
#
# ✔  success   LiSA - Thrill, Risk, Heartless
#   › /content/d-fi-linux-x64/Music/LiSA - Thrill Risk Heartless/01 - Thrill Risk Heartless.mp3
#
#
#
# ☒  complete  Finished downloading album "Thrill, Risk, Heartless"
#
#
#   [========================================] | 100% | Jet Rocket
#
#
#   [========================================] | 100% | Believe in Myself
#   [========================================] | 100% | Will Mushoku Toumei
#
#
#   [==================================------] | 86% | Bright Flight
#
#   [=================================-------] | 83% | Shirushi
#   [========================================] | 100% | Datte Atashino Hero
#   [========================================] | 100% | ID
#   [====================================----] | 90% | Träumerei
#   [======================================--] | 95% | L.Miranic
#   [=================================-------] | 82% | Little Devil Parade✔  success   LiSA - I'm a Rock Star
#   › /content/d-fi-linux-x64/Music/LiSA - Best Day Best Way/02 - I'm a Rock Star.mp3
# ✔  success   LiSA - Best Day, Best Way
#   › /content/d-fi-linux-x64/Music/LiSA - Best Day Best Way/01 - Best Day Best Way.mp3
# ✔  success   LiSA - Best Day, Best Way (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Best Day Best Way/04 - Best Day Best Way (Instrumental).mp3
# ✔  success   LiSA - Shiroitoiki
#   › /content/d-fi-linux-x64/Music/LiSA - Best Day Best Way/03 - Shiroitoiki.mp3
# ☒  complete  Finished downloading album "Best Day, Best Way"
#
#
#
#
#
#
#   [========================================] | 100% | Blue Moon
#
#   [========================================] | 100% | Catch the Moment
#
#
#   [========================================] | 100% | Brave Freak Out
#   [========================================] | 100% | Tokyo Love Song
#   [=====================================---] | 93% | Today
#   [========================================] | 100% | Ookamito Misanga
#   [======================================--] | 95% | Soshite Paradeha Tsuzuku
#   [========================================] | 100% | Jump!!
#
#   [========================================] | 100% | Little Devil Parade
#
# ✔  success   LiSA - Empty Mermaid
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (First Edition)/01 - Empty Mermaid.mp3
# ✔  success   LiSA - Kyomu
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (First Edition)/03 - Kyomu.mp3
# ✔  success   LiSA - Risky
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (First Edition)/02 - Risky.mp3
# ☒  complete  Finished downloading album "Empty Mermaid (First Edition)"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Brave Freak Out (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out - EP/04 - Brave Freak Out (Instrumental).mp3
# ✔  success   LiSA - Axxxis
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out - EP/02 - Axxxis.mp3
# ✔  success   LiSA - Tsuyogari Fanfare
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out - EP/03 - Tsuyogari Fanfare.mp3
# ✔  success   LiSA - Brave Freak Out
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out - EP/01 - Brave Freak Out.mp3
# ☒  complete  Finished downloading album "Brave Freak Out - EP"
#
#
#
#
#
#
#
# ✔  success   LiSA - I Doubt It
#   › /content/d-fi-linux-x64/Music/LiSA - traumerei/02 - I Doubt It.mp3
# ✔  success   LiSA - Träumerei
#   › /content/d-fi-linux-x64/Music/LiSA - traumerei/01 - Träumerei.mp3
# ✔  success   LiSA - Träumerei (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - traumerei/04 - Träumerei (Instrumental).mp3
# ✔  success   LiSA - Spice
#   › /content/d-fi-linux-x64/Music/LiSA - traumerei/03 - Spice.mp3
# ☒  complete  Finished downloading album "traumerei"
#
#
#
#   [========================================] | 100% | Kimini Piero
#
#
#   [========================================] | 99% | Orange Cider (Live at Toyos
#   [========================================] | 100% | Rapid Life Syndrome (Live
#
#
#
#   [========================================] | 100% | Elect Lyrical (Live at Toy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Only Not Equal Lonely
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - ID (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - ID/04 - ID (Instrumental).mp3
# ✔  success   LiSA - Gift Gift
#   › /content/d-fi-linux-x64/Music/LiSA - ID/02 - Gift Gift.mp3
# ✔  success   LiSA - Gift Gift (Christmas Version)
#   › /content/d-fi-linux-x64/Music/LiSA - ID/03 - Gift Gift (Christmas Version).mp3
# ✔  success   LiSA - ID
#   › /content/d-fi-linux-x64/Music/LiSA - ID/01 - ID.mp3
# ☒  complete  Finished downloading album "ID"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Catch the Moment
#   › /content/d-fi-linux-x64/Music/LiSA - Catch the Moment/01 - Catch the Moment.mp3
# ✔  success   LiSA - Merry Hurry Berry
#   › /content/d-fi-linux-x64/Music/LiSA - Catch the Moment/03 - Merry Hurry Berry.mp3
# ✔  success   LiSA - Ring a Bell
#   › /content/d-fi-linux-x64/Music/LiSA - Catch the Moment/02 - Ring a Bell.mp3
# ☒  complete  Finished downloading album "Catch the Moment"
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Lovely Day
#   › /content/d-fi-linux-x64/Music/LiSA - Lucky Hi Five!/01 - Lovely Day.mp3
# ✔  success   LiSA - Psychedelic Drive
#   › /content/d-fi-linux-x64/Music/LiSA - Lucky Hi Five!/03 - Psychedelic Drive.mp3
# ✔  success   LiSA - She
#   › /content/d-fi-linux-x64/Music/LiSA - Lucky Hi Five!/04 - She.mp3
# ✔  success   LiSA - Get Free
#   › /content/d-fi-linux-x64/Music/LiSA - Lucky Hi Five!/06 - Get Free.mp3
# ✔  success   LiSA - Halo-Halo
#   › /content/d-fi-linux-x64/Music/LiSA - Lucky Hi Five!/05 - Halo-Halo.mp3
# ✔  success   LiSA - Hi Five!
#   › /content/d-fi-linux-x64/Music/LiSA - Lucky Hi Five!/02 - Hi Five!.mp3
# ✔  success   LiSA - Owaranai Bouken
#   › /content/d-fi-linux-x64/Music/LiSA - Lucky Hi Five!/07 - Owaranai Bouken.mp3
# ☒  complete  Finished downloading album "Lucky Hi Five!"
#   [======================================--] | 95% | Oath Sign (Acoustic Version
#
#
#   [========================================] | 100% | Jet Rocket
#
#   [========================================] | 100% | Rock Mode
#   [========================================] | 100% | LOVER"S"MiLE
#   [===================---------------------] | 47% | Owari No Nai Uta
#   [========================================] | 100% | Now and Future
#   [========================================] | 100% | Ysashisani Tadori Tsukumad
#   [========================================] | 100% | Oath Sign
#   [===================================-----] | 89% | Hana To Mitsubachi
#   [========================================] | 100% | Un Fil
# ✔  success   LiSA - Gurenge (TV Version)
#   › /content/d-fi-linux-x64/Music/LiSA - Gurenge/05 - Gurenge (TV Version).mp3
# ✔  success   LiSA - Propaganda
#   › /content/d-fi-linux-x64/Music/LiSA - Gurenge/02 - Propaganda.mp3
# ✔  success   LiSA - Gurenge (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Gurenge/04 - Gurenge (Instrumental).mp3
# ✔  success   LiSA - Gurenge
#   › /content/d-fi-linux-x64/Music/LiSA - Gurenge/01 - Gurenge.mp3
# ✔  success   LiSA - Yakusokuno Uta
#   › /content/d-fi-linux-x64/Music/LiSA - Gurenge/03 - Yakusokuno Uta.mp3
# ☒  complete  Finished downloading album "Gurenge"
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Wake Up! Sloth
#   › /content/d-fi-linux-x64/Music/LiSA - Rally Go Round/03 - Wake Up! Sloth.mp3
# ✔  success   LiSA - Rally Go Round
#   › /content/d-fi-linux-x64/Music/LiSA - Rally Go Round/01 - Rally Go Round.mp3
# ✔  success   LiSA - Orange Cider
#   › /content/d-fi-linux-x64/Music/LiSA - Rally Go Round/02 - Orange Cider.mp3
# ✔  success   LiSA - Rally Go Round (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Rally Go Round/04 - Rally Go Round (Instrumental).mp3
# ☒  complete  Finished downloading album "Rally Go Round"
#   [========================================] | 100% | Mushokutoumei
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Poker Face
#   › /content/d-fi-linux-x64/Music/LiSA - Rising Hope/02 - Poker Face.mp3
# ✔  success   LiSA - Rising Hope
#   › /content/d-fi-linux-x64/Music/LiSA - Rising Hope/01 - Rising Hope.mp3
# ✔  success   LiSA - Rising Hope (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Rising Hope/04 - Rising Hope (Instrumental).mp3
# ✔  success   LiSA - Ashiato Compass
#   › /content/d-fi-linux-x64/Music/LiSA - Rising Hope/03 - Ashiato Compass.mp3
# ☒  complete  Finished downloading album "Rising Hope"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Brave Freak Out (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out (Special Edition)/05 - Brave Freak Out (Instrumental).mp3
#
#
#
#
# ✔  success   LiSA - Brave Freak Out
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out (Special Edition)/01 - Brave Freak Out.mp3
# ✔  success   LiSA - Shuffle
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out (Special Edition)/04 - Shuffle.mp3
# ✔  success   LiSA - Axxxis
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out (Special Edition)/02 - Axxxis.mp3
# ✔  success   LiSA - Tsuyogari Fanfare
#   › /content/d-fi-linux-x64/Music/LiSA - Brave Freak Out (Special Edition)/03 - Tsuyogari Fanfare.mp3
# ☒  complete  Finished downloading album "Brave Freak Out (Special Edition)"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - L.Miranic
#   › /content/d-fi-linux-x64/Music/LiSA - Bright Flight - L.Miranic/02 - L.Miranic.mp3
# ✔  success   LiSA - Bright Flight
#   › /content/d-fi-linux-x64/Music/LiSA - Bright Flight - L.Miranic/01 - Bright Flight.mp3
# ✔  success   LiSA - Tokyo Love Song
#   › /content/d-fi-linux-x64/Music/LiSA - Bright Flight - L.Miranic/03 - Tokyo Love Song.mp3
# ☒  complete  Finished downloading album "Bright Flight / L.Miranic"
#
#
# ✔  success   LiSA - Unlasting (TV Version)
#   › /content/d-fi-linux-x64/Music/LiSA - Unlasting/06 - Unlasting (TV Version).mp3
# ✔  success   LiSA - Howl
#   › /content/d-fi-linux-x64/Music/LiSA - Unlasting/02 - Howl.mp3
# ✔  success   LiSA - Unlasting (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Unlasting/05 - Unlasting (Instrumental).mp3
# ✔  success   LiSA - Unlasting
#   › /content/d-fi-linux-x64/Music/LiSA - Unlasting/01 - Unlasting.mp3
# ✔  success   LiSA - Chill-Chill-Dal-Da
#   › /content/d-fi-linux-x64/Music/LiSA - Unlasting/04 - Chill-Chill-Dal-Da.mp3
# ✔  success   LiSA - KALEIDO
#   › /content/d-fi-linux-x64/Music/LiSA - Unlasting/03 - KALEIDO.mp3
# ☒  complete  Finished downloading album "Unlasting"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [----------------------------------------] | 0% | Shirushi
#   [----------------------------------------] | 0% | L.Miranic
#   [----------------------------------------] | 0% | Little Devil Parade
# ✔  success   LiSA - Tsumibito
#   › /content/d-fi-linux-x64/Music/LiSA - Ash/02 - Tsumibito.mp3
# ✔  success   LiSA - Ash (Instrumental)
#   › /content/d-fi-linux-x64/Music/LiSA - Ash/04 - Ash (Instrumental).mp3
# ✔  success   LiSA - Ash
#   › /content/d-fi-linux-x64/Music/LiSA - Ash/01 - Ash.mp3
# ✔  success   LiSA - Only Not Equal Lonely
#   › /content/d-fi-linux-x64/Music/LiSA - Ash/03 - Only Not Equal Lonely.mp3
# ☒  complete  Finished downloading album "Ash"
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Orange Cider (Live at Toyo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Oath Sign (Acoustic Versio
#   [========================================] | 100% | Hana To Mitsubachi
#   [===================================-----] | 88% | Owari No Nai Uta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Shirushi
#   [========================================] | 100% | L.Miranic
#   [========================================] | 100% | Little Devil Parade
#   [----------------------------------------] | 0% | Träumerei
#   [----------------------------------------] | 0% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Today
#
#   [========================================] | 100% | Soshite Paradeha Tsuzuku
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [====================================----] | 90% | Owari No Nai Uta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [==--------------------------------------] | 5% | Träumerei
#   [==--------------------------------------] | 4% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [====================================----] | 91% | Owari No Nai Uta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Kakuseiya
#   › /content/d-fi-linux-x64/Music/LiSA - Letters to U (For EMD)/05 - Kakuseiya.mp3
# ✔  success   LiSA - Escape Game
#   › /content/d-fi-linux-x64/Music/LiSA - Letters to U (For EMD)/04 - Escape Game.mp3
# ✔  success   LiSA - Eien
#   › /content/d-fi-linux-x64/Music/LiSA - Letters to U (For EMD)/03 - Eien.mp3
# ✔  success   LiSA - Miraikaze
#   › /content/d-fi-linux-x64/Music/LiSA - Letters to U (For EMD)/02 - Miraikaze.mp3
# ✔  success   LiSA - Mousou Controller
#   › /content/d-fi-linux-x64/Music/LiSA - Letters to U (For EMD)/06 - Mousou Controller.mp3
# ✔  success   LiSA - Believe in Myself
#   › /content/d-fi-linux-x64/Music/LiSA - Letters to U (For EMD)/01 - Believe in Myself.mp3
# ✔  success   LiSA - Mushokutoumei
#   › /content/d-fi-linux-x64/Music/LiSA - Letters to U (For EMD)/07 - Mushokutoumei.mp3
# ☒  complete  Finished downloading album "Letters to U (For EMD)"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [====------------------------------------] | 9% | Träumerei
#   [===-------------------------------------] | 8% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=======================================-] | 97% | Owari No Nai Uta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=====-----------------------------------] | 12% | Träumerei
#   [====------------------------------------] | 10% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Owari No Nai Uta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [======----------------------------------] | 15% | Träumerei
#   [=====-----------------------------------] | 14% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Bad Sweet Trap (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/11 - Bad Sweet Trap (Live at Toyosu Pit 2015).mp3
# ✔  success   LiSA - Antihero (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/09 - Antihero (Live at Toyosu Pit 2015).mp3
# ✔  success   LiSA - Rising Hope (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/12 - Rising Hope (Live at Toyosu Pit 2015).mp3
# ✔  success   LiSA - Mitsu
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/05 - Mitsu.mp3
# ✔  success   LiSA - Kyomu
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/03 - Kyomu.mp3
# ✔  success   LiSA - Empty Mermaid
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/01 - Empty Mermaid.mp3
# ✔  success   LiSA - Mr. Launcher (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/14 - Mr. Launcher (Live at Toyosu Pit 2015).mp3
# ✔  success   LiSA - Risky
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/02 - Risky.mp3
# ✔  success   LiSA - L. Miranic (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/06 - L. Miranic (Live at Toyosu Pit 2015).mp3
# ✔  success   LiSA - Rally Go Round (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/10 - Rally Go Round (Live at Toyosu Pit 2015).mp3
# ✔  success   LiSA - Rapid Life Syndrome (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/04 - Rapid Life Syndrome (Live at Toyosu Pit 2015).mp3
# ✔  success   LiSA - Elect Lyrical (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/13 - Elect Lyrical (Live at Toyosu Pit 2015).mp3
# ✔  success   LiSA - Kimini Piero
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/08 - Kimini Piero.mp3
# ✔  success   LiSA - Orange Cider (Live at Toyosu Pit 2015)
#   › /content/d-fi-linux-x64/Music/LiSA - Empty Mermaid (Limited Edition)/07 - Orange Cider (Live at Toyosu Pit 2015).mp3
# ☒  complete  Finished downloading album "Empty Mermaid (Limited Edition)"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=======---------------------------------] | 18% | Träumerei
#   [======----------------------------------] | 16% | Bright Flight
# ✔  success   LiSA - Fragile Vampire
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/08 - Fragile Vampire.mp3
# ✔  success   LiSA - Kimini Piero
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/12 - Kimini Piero.mp3
# ✔  success   LiSA - Elect Lyrical
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/11 - Elect Lyrical.mp3
# ✔  success   LiSA - Bright Flight
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/06 - Bright Flight.mp3
# ✔  success   LiSA - Shirushi
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/14 - Shirushi.mp3
# ✔  success   LiSA - Antihero
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/09 - Antihero.mp3
# ✔  success   LiSA - Rapid Life Syndrome
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/03 - Rapid Life Syndrome.mp3
# ✔  success   LiSA - No More Time Machine
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/13 - No More Time Machine.mp3
# ✔  success   LiSA - Mr.Launcher
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/01 - Mr.Launcher.mp3
# ✔  success   LiSA - L.Miranic
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/07 - L.Miranic.mp3
# ✔  success   LiSA - Rising Hope
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/02 - Rising Hope.mp3
# ✔  success   LiSA - Akogare Bouenkyou
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/05 - Akogare Bouenkyou.mp3
# ✔  success   LiSA - Bad Sweet Trap
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/10 - Bad Sweet Trap.mp3
# ✔  success   LiSA - Mitsu
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/04 - Mitsu.mp3
# ☒  complete  Finished downloading album "Launcher"
#
# ✔  success   LiSA - Brave Freak Out
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/10 - Brave Freak Out.mp3
# ✔  success   LiSA - Mr.Launcher
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/12 - Mr.Launcher.mp3
# ✔  success   LiSA - Oath Sign
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/03 - Oath Sign.mp3
# ✔  success   LiSA - Thrill, Risk, Heartless
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/02 - Thrill Risk Heartless.mp3
# ✔  success   LiSA - Rally Go Round
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/05 - Rally Go Round.mp3
# ✔  success   LiSA - Cosmic Jet Coaster
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/09 - Cosmic Jet Coaster.mp3
# ✔  success   LiSA - Ash
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/04 - Ash.mp3
# ✔  success   LiSA - Believe in Ourselves
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/13 - Believe in Ourselves.mp3
# ✔  success   LiSA - No More Time Machine
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/07 - No More Time Machine.mp3
# ✔  success   LiSA - Hi Five!
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/08 - Hi Five!.mp3
# ✔  success   LiSA - Hello Good Day
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/06 - Hello Good Day.mp3
# ✔  success   LiSA - Rock Mode'18
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/11 - Rock Mode'18.mp3
# ✔  success   LiSA - Catch the Moment
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/01 - Catch the Moment.mp3
# ✔  success   LiSA - Best Day, Best Way
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Way)/14 - Best Day Best Way.mp3
# ☒  complete  Finished downloading album "LiSA Best (Way)"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========--------------------------------] | 21% | Träumerei
#   [========--------------------------------] | 19% | Bright Flight
# ✔  success   LiSA - Peace Beat Beast
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/09 - Peace Beat Beast.mp3
# ✔  success   LiSA - The End of My World
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/04 - The End of My World.mp3
# ✔  success   LiSA - Empty Mermaid
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/08 - Empty Mermaid.mp3
# ✔  success   LiSA - Rally Go Round
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/07 - Rally Go Round.mp3
# ✔  success   LiSA - Loser: Kiboutomirainimuennocatharsis
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/03 - Loser Kiboutomirainimuennocatharsis.mp3
# ✔  success   LiSA - Jump!!
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/05 - Jump!!.mp3
# ✔  success   LiSA - Blue Moon
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/10 - Blue Moon.mp3
# ✔  success   LiSA - Little Devil Parade
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/01 - Little Devil Parade.mp3
# ✔  success   LiSA - Ookamito Misanga
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/06 - Ookamito Misanga.mp3
# ✔  success   LiSA - Catch the Moment
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/02 - Catch the Moment.mp3
# ✔  success   LiSA - Brave Freak Out
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/11 - Brave Freak Out.mp3
# ✔  success   LiSA - Soshite Paradeha Tsuzuku
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/13 - Soshite Paradeha Tsuzuku.mp3
# ✔  success   LiSA - Today
#   › /content/d-fi-linux-x64/Music/LiSA - Little Devil Parade/12 - Today.mp3
# ☒  complete  Finished downloading album "Little Devil Parade"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [==========------------------------------] | 25% | Träumerei
#   [=========-------------------------------] | 22% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [===========-----------------------------] | 27% | Träumerei
#   [==========------------------------------] | 25% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [============----------------------------] | 30% | Träumerei
#   [===========-----------------------------] | 28% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=============---------------------------] | 32% | Träumerei
#   [============----------------------------] | 30% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [==============--------------------------] | 36% | Träumerei
#   [=============---------------------------] | 33% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [===============-------------------------] | 38% | Träumerei
#   [==============--------------------------] | 35% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=================-----------------------] | 42% | Träumerei
#   [===============-------------------------] | 39% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [==================----------------------] | 45% | Träumerei
#   [================------------------------] | 41% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [===================---------------------] | 48% | Träumerei
#   [==================----------------------] | 44% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [====================--------------------] | 51% | Träumerei
#   [===================---------------------] | 47% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=====================-------------------] | 53% | Träumerei
#   [====================--------------------] | 49% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=======================-----------------] | 57% | Träumerei
#   [=====================-------------------] | 52% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================----------------] | 61% | Träumerei
#   [======================------------------] | 55% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=========================---------------] | 63% | Träumerei
#   [=======================-----------------] | 59% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [==========================--------------] | 66% | Träumerei
#   [========================----------------] | 61% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [============================------------] | 69% | Träumerei
#   [=========================---------------] | 63% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=============================-----------] | 72% | Träumerei
#   [==========================--------------] | 66% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [==============================----------] | 76% | Träumerei
#   [===========================-------------] | 68% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [===============================---------] | 78% | Träumerei
#   [=============================-----------] | 72% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [================================--------] | 81% | Träumerei
#   [==============================----------] | 75% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=================================-------] | 84% | Träumerei
#   [===============================---------] | 78% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [===================================-----] | 87% | Träumerei
#   [================================--------] | 80% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [====================================----] | 90% | Träumerei
#   [=================================-------] | 82% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [======================================--] | 94% | Träumerei
#   [==================================------] | 86% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=======================================-] | 96% | Träumerei
#   [===================================-----] | 88% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 99% | Träumerei
#   [=====================================---] | 92% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 100% | Träumerei
#   [======================================--] | 94% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [=======================================-] | 96% | Bright Flight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   [========================================] | 99% | Bright Flight
# ✔  success   LiSA - Empty Mermaid
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/06 - Empty Mermaid.mp3
# ✔  success   LiSA - Rising Hope
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/01 - Rising Hope.mp3
# ✔  success   LiSA - Crossing Field
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/02 - Crossing Field.mp3
# ✔  success   LiSA - Axxxis
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/05 - Axxxis.mp3
# ✔  success   LiSA - Will Mushoku Toumei
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/13 - Will Mushoku Toumei.mp3
# ✔  success   LiSA - Believe in Myself
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/14 - Believe in Myself.mp3
# ✔  success   LiSA - ID
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/11 - ID.mp3
# ✔  success   LiSA - Jet Rocket
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/07 - Jet Rocket.mp3
# ✔  success   LiSA - Datte Atashino Hero
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/03 - Datte Atashino Hero.mp3
# ✔  success   LiSA - L.Miranic
#   › Used undefined - undefined #486434872 as alternative
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/L.Miranic.mp3
# ✔  success   LiSA - Little Devil Parade
#   › Used undefined - undefined #486434892 as alternative
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/Little Devil Parade.mp3
# ✔  success   LiSA - Shirushi
#   › Used undefined - undefined #486434812 as alternative
#   › /content/d-fi-linux-x64/Music/LiSA - LiSA Best (Day)/Shirushi.mp3
# ✔  success   LiSA - Träumerei
#   › Used undefined - undefined #101466172 as alternative
#   › /content/d-fi-linux-x64/Music/LiSA - traumerei/Träumerei.mp3
# ✔  success   LiSA - Bright Flight
#   › Used undefined - undefined #101463056 as alternative
#   › /content/d-fi-linux-x64/Music/LiSA - Launcher/Bright Flight.mp3
# ☒  complete  Finished downloading album "LiSA Best (Day)"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ✔  success   LiSA - Egoistic Shooter
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/04 - Egoistic Shooter.mp3
# ✔  success   LiSA - Warattehoshikute
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/08 - Warattehoshikute.mp3
# ✔  success   LiSA - Wild Candy
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/05 - Wild Candy.mp3
# ✔  success   LiSA - Oath Sign
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/02 - Oath Sign.mp3
# ✔  success   LiSA - Now and Future
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/03 - Now and Future.mp3
# ✔  success   LiSA - LOVER"S"MiLE
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/11 - LOVERSMiLE.mp3
# ✔  success   LiSA - Un Fil
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/09 - Un Fil.mp3
# ✔  success   LiSA - Ysashisani Tadori Tsukumade
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/01 - Ysashisani Tadori Tsukumade.mp3
# ✔  success   LiSA - Rock Mode
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/07 - Rock Mode.mp3
# ✔  success   LiSA - Jet Rocket
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/10 - Jet Rocket.mp3
# ✔  success   LiSA - Oath Sign (Acoustic Version)
#   › Used undefined - undefined #589112022 as alternative
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/Oath Sign (Acoustic Version).mp3
# ✔  success   LiSA - Hana To Mitsubachi
#   › Used undefined - undefined #589111952 as alternative
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/Hana To Mitsubachi.mp3
# ✔  success   LiSA - Owari No Nai Uta
#   › Used undefined - undefined #589112012 as alternative
#   › /content/d-fi-linux-x64/Music/LiSA - LOVERSMiLE/Owari No Nai Uta.mp3
# ☒  complete  Finished downloading album "LOVER"S"MiLE"

# %%
#If downloaded only whats required

# archive name (below)
!7z -v300m -mx1 -mmt4 a "lisa" "/content/d-fi-linux-x64/Music"
# !find -name "*.7z.*" -exec bash -c 'mv "{}" "/content/drive/My Drive/Music/"' {} \;
# !rm -rf "/content/d-fi-linux-x64/Music"
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive:
# 30 folders, 173 files, 1840337150 bytes (1756 MiB)
#
# Creating archive: lisa.7z
#
# Items to compress: 203
#
# 100% 173 + Music/LiSA - traumerei/Träumerei.mp3
# Files read from disk: 173
# Archive size: 1821532400 bytes (1738 MiB)
# Everything is Ok

# %%
#If downloaded extra shit

# !mkdir "/content/Music"
#artist name to move (below)
# !find -name " *"  -type d -exec bash -c 'mv "{}" "/content/Music"' {} \;
#archive name (below)
!7z -v300m -mx1 -mmt4 a "Hiroyuki Sawano" "/content/d-fi-linux-x64/Music"
# !find -name "*.7z.*" -exec bash -c 'mv "{}" "/content/drive/My Drive/Music/"' {} \;
# !rm -rf "/content/d-fi-linux-x64/Music"
# !rm -rf "/content/Music"

# %% [markdown]
# #Export Discord Chat

# %%
# !sudo apt-get install -y gpg
# !wget -qO- https://packages.microsoft.com/keys/microsoft.asc | gpg --dearmor -o microsoft.asc.gpg
# !sudo mv microsoft.asc.gpg /etc/apt/trusted.gpg.d/
# !wget -q https://packages.microsoft.com/config/ubuntu/19.04/prod.list
# !sudo mv prod.list /etc/apt/sources.list.d/microsoft-prod.list
# !sudo chown root:root /etc/apt/trusted.gpg.d/microsoft.asc.gpg
# !sudo chown root:root /etc/apt/sources.list.d/microsoft-prod.list
# !sudo apt-get install -y apt-transport-https
# !sudo apt-get update
# !sudo apt-get install dotnet-runtime-3.1

# %%
# !wget https://github.com/Tyrrrz/DiscordChatExporter/releases/download/2.17/DiscordChatExporter.CLI.zip

# %%
!7z -o* x DiscordChatExporter.CLI.zip

# %%
# %cd DiscordChatExporter.CLI

# %%
# !dotnet DiscordChatExporter.Cli.dll export -f HtmlDark -o "/content/a" -t NjAwODg4NzE0MzM5NjgwMjU3.Xckr4A.wlBIG9DF0lC1v0u_LTo9Da0_a7Y -c 541811241824288779
